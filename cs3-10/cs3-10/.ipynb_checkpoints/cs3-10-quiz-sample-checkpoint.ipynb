# %%
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image, ImageFilter

# %%
img = Image.open("cs3-10-quiz.jpg")

# %%
print(img.format, img.size, img.width, img.height, img.mode)
# Out:
# JPEG (1920, 2560) 1920 2560 RGB

# %%
data = np.array(img)
print(data.shape)
# Out:
# (2560, 1920, 3)

# %%
img_rot = img.rotate(-40)
plt.imshow(img_rot)
plt.show()

# %%
img_out = "cs3-10-quiz-rot.jpg"
img_rot.save(img_out, quality=95)
