# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv("../cs3-04/running.csv", sep =",")
print(df.shape)
print(df.info())
display(df.head())
# Out:
# (47, 4)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 47 entries, 0 to 46
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   ID      47 non-null     int64
#  1   Univ    47 non-null     object
#  2   Grade   47 non-null     int64
#  3   Time    47 non-null     int64
# dtypes: int64(3), object(1)
# memory usage: 1.6+ KB
# None
#      ID Univ  Grade  Time
# 0  1001    D      3  1870
# 1  1004    C      1  1957
# 2  1006    D      2  2063
# 3  1007    D      3  1839
# 4  1008    C      2  1740

# %%
print(df["Grade"].value_counts())
# Out:
# Grade
# 3    14
# 1    11
# 2    11
# 4    11
# Name: count, dtype: int64

# %%
display(pd.crosstab(df["Univ"], df["Grade"]))
# Out:
# Grade  1  2  3  4
# Univ
# A      3  4  5  4
# B      2  1  2  3
# C      1  3  1  3
# D      5  3  6  1

# %%
display(df.sort_values("Time", ascending=True))
# Out:
#       ID Univ  Grade  Time
# 4   1008    C      2  1740
# 26  1030    D      3  1761
# 38  1042    A      3  1764
# 8   1012    A      3  1783
# 24  1028    B      4  1785
# 32  1036    D      1  1800
# 10  1014    D      1  1803
# 7   1011    A      3  1818
# 22  1026    A      4  1825
# 27  1031    A      2  1826
# 3   1007    D      3  1839
# 23  1027    B      1  1850
# 41  1045    D      3  1870
# 0   1001    D      3  1870
# 28  1032    B      1  1871
# 21  1025    A      1  1874
# 34  1038    A      4  1875
# 40  1044    D      2  1878
# 37  1041    B      4  1879
# 29  1033    A      3  1888
# 31  1035    D      3  1894
# 36  1040    D      3  1895
# 16  1020    D      1  1897
# 35  1039    A      3  1923
# 12  1016    D      4  1924
# 14  1018    D      1  1926
# 18  1022    C      4  1926
# 44  1048    D      2  1930
# 13  1017    C      4  1932
# 15  1019    C      3  1937
# 30  1034    C      2  1940
# 20  1024    D      1  1947
# 1   1004    C      1  1957
# ...
